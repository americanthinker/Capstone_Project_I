# %%
df = pd.read_csv('EM_anon.csv', encoding = "ISO-8859-1")

# %%
pd.set_option('display.max_colwidth', 300)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df.head()
# Out:
#                    Id           AccountId Salutation Title Birthdate             OwnerId     CreatedDate         CreatedById LastModifiedDate    LastModifiedById SystemModstamp LastActivityDate What_is_your_current_location__c            City State How_did_you_hear_about_Elite_Meet__c Are_you_currently_seeking_to_join_Elite__c Your_transition_to_civilian_life_begin__c Undergrad__c Undergraduate_School__c Grad_Degree__c Graduate_School__c Years_of_Service__c Military_specialty_in_real_words__c                                                                     Whichcourse__c When_did_you_graduate__c What_was_your_first_unit_after_grad__c What_locations_do_you_WANT_to_live_in__c Where_do_you_NOT_WANT_to_live__c What_would_be_your_ideal_next_job__c Target_Industries_Pls_pick_up_to_Three__c Company_that_you_re_interested_in__c of_informational_interviews_completed__c of_job_formal_interviews_completed__c of_counting_getting_a_job_through_EM__c What_s_more_important_to_you__c How_mobile_a
# ...

# %%
df['What_is_your_current_location__c'].value_counts()
# Out:
# San Diego,CA             120
# Virginia Beach,VA        106
# New York,NY               99
# Washington,DC             39
# Fort Bragg,NC             28
#                         ...
# 4431 E Angela Dr           1
# Scandia,MN                 1
# Melville,NY                1
# Briarcliff Manor,NY        1
# Huntington Station,NY      1
# Name: What_is_your_current_location__c, Length: 358, dtype: int64

# %%
df['State'].value_counts()
# Out:
# CA                  212
# NY                  168
# VA                  159
# NC                   99
# TX                   80
# FL                   52
# WA                   48
# DC                   39
# GA                   37
# TN                   31
# CO                   30
# MA                   30
# IL                   27
# USA                  21
# NJ                   21
# HI                   19
# PA                   15
# CT                   14
# MD                   12
# KY                   12
# AZ                    9
# Deployed              8
# SC                    7
# AL                    7
# MI                    6
# UT                    5
# Germany               5
# OCONUS                5
# MO                    5
# LA                    5
# NV                    5
# MN                    4
# OH                    3
# Japan                 3
# WI                    3
# NM                    3
# Philippines           2
# OK                    2
# ...

# %%
df['State'] = df['State'].str.strip()

# %%
df['City'] = df['City'].str.strip()

# %%
df['What_is_your_current_location__c'] = df['What_is_your_current_location__c'].str.strip()

# %%
df.to_csv('test_anon.csv', header=True, index=False)
