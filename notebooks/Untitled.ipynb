# %%
df = pd.read_csv('Contact.csv', encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#                    Id  IsDeleted  MasterRecordId           AccountId Salutation FirstName     LastName     RecordTypeId  OtherStreet  OtherCity  OtherState  OtherPostalCode  OtherCountry  OtherLatitude  OtherLongitude  OtherGeocodeAccuracy      MailingStreet    MailingCity MailingState  MailingPostalCode MailingCountry  MailingLatitude  MailingLongitude  MailingGeocodeAccuracy           Phone             Fax     MobilePhone       HomePhone      OtherPhone  AssistantPhone  ...  Grad_Degree__c Graduate_School__c Years_of_Service__c  Military_specialty_in_real_words__c                                                                     Whichcourse__c When_did_you_graduate__c What_was_your_first_unit_after_grad__c What_locations_do_you_WANT_to_live_in__c Where_do_you_NOT_WANT_to_live__c  What_would_be_your_ideal_next_job__c  Target_Industries_Pls_pick_up_to_Three__c  Company_that_you_re_interested_in__c of_informational_interviews_completed__c of_job_formal_interviews_completed__c of_cou
# ...

# %%
sum(df['Lead_RecordType__c'].isna())
# Out:
# 801
